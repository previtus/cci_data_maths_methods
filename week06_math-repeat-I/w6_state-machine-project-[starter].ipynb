# %% [markdown]
# # State Machine Project

# %% [markdown]
# **The task was:** write a python code which would accommodate any model of state machine and control something with it (simple examples of outputs were: colors, sounds in a loop). Idea: This goes beyond simple “press button -> do action” behavior. We can mimic intelligent behavior with this (remember the Batman game example).
#
# Let's say that we always have just one possible path ahead of us (**deterministic state machine**).

# %% [markdown]
# ## Pseudocode idea

# %%
states = [1, 2, 3, 4]
allowed_alphabet = [ abc... ]
starting_state = 1

current_state = starting_state # later change this
transitions = [ list_of_dictionaries_of_transitions ]
# for example: transitions_state_1 = { "a": 2 }
encodings = { state_number : encoded_color }

while True:
    signal = get_input_from_user (ask)
    if it_is_from_allowed_alphabet:
        # Get where we get from the current state with the observed signal
        get_current_transitions # as a dictionary from transitions and the current state
        change_current_state

    output = encode_the_new_state
    somehow show the output
